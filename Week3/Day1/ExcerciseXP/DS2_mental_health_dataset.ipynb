# %%
import pandas as pd
from pathlib import Path
csv_path = Path.home() / "Downloads" /"Global Trends in Mental Health Disorder"/"Mental health Depression disorder Data.csv"   # <-- change this
df_mental_health = pd.read_csv(csv_path)
df_mental_health.head(30)
# Out:
# /var/folders/zs/lhn3v0dx0v32gt7hm_r0m1zc0000gn/T/ipykernel_63566/991666583.py:4: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mental_health = pd.read_csv(csv_path)
#     index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0       0  Afghanistan  AFG  1990           0.16056             0.697779
# 1       1  Afghanistan  AFG  1991          0.160312             0.697961
# 2       2  Afghanistan  AFG  1992          0.160135             0.698107
# 3       3  Afghanistan  AFG  1993          0.160037             0.698257
# 4       4  Afghanistan  AFG  1994          0.160022             0.698469
# 5       5  Afghanistan  AFG  1995          0.160076             0.698695
# 6       6  Afghanistan  AFG  1996          0.160249             0.698914
# 7       7  Afghanistan  AFG  1997          0.160554             0.699127
# 8       8  Afghanistan  AFG  1998          0.160931             0.699372
# ...

# %%
rows,cols = df_mental_health.shape
print("Rows:", rows, "Columns:", cols)
# Out:
# Rows: 108553 Columns: 11

# %%
df_mental_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108553 entries, 0 to 108552
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      108553 non-null  int64
#  1   Entity                     108553 non-null  object
#  2   Code                       103141 non-null  object
#  3   Year                       108553 non-null  object
#  4   Schizophrenia (%)          25875 non-null   object
#  5   Bipolar disorder (%)       19406 non-null   object
#  6   Eating disorders (%)       100236 non-null  object
#  7   Anxiety disorders (%)      6468 non-null    float64
#  8   Drug use disorders (%)     6468 non-null    float64
#  9   Depression (%)             6468 non-null    float64
#  10  Alcohol use disorders (%)  6468 non-null    float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 9.1+ MB

# %% [markdown]
# Dataset: "Global Trends in Mental Health Disorder"
# 1. This dataset contains 108553 rows and 11 columns.
# 2. Columns include country,year and  different types of mental health disorders
# 3. This dataset helps to analyze prevelence of mental health disorders in different countries over years.

# %%
df_mental_health.columns
# Out:
# Index(['index', 'Entity', 'Code', 'Year', 'Schizophrenia (%)',
#        'Bipolar disorder (%)', 'Eating disorders (%)', 'Anxiety disorders (%)',
#        'Drug use disorders (%)', 'Depression (%)',
#        'Alcohol use disorders (%)'],
#       dtype='object')

# %% [markdown]
# Columns:
# 'index'                     - qualitative    - It’s just an identifier
# 'Entity'                    - qualitative    - Represented by differnt countries as a text category .
# 'Code'                      - qualitative    - Abbreviation of a country (stored as text)
# 'Year'                      - quantitative   - Represents numberic time values that can be ordered
# 'Schizophrenia (%)'         - quantitative   - represents % of population with Schizophrenia, a numeric measure
# 'Bipolar disorder (%)'      - quantitative   - represents % of population with Bipolar disorder a numeric measure
# 'Eating disorders (%)'      - quantitative   - represents % of population with Eating disorders, a numeric measure
# 'Anxiety disorders (%)'     - quantitative   - represents % of population with Anxiety disorders, a numeric measure
# 'Drug use disorders (%)'    - quantitative   - represents % of population with Drug use disorders, a numeric measure
# 'Depression (%)'            - quantitative   - represents % of population with Depression, a numeric measure
# 'Alcohol use disorders (%)' - quantitative   - represents % of population with Alcohol use disorders, a numeric measure
